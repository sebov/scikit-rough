# %%
from skrough.algorithms import hooks
from skrough.algorithms.meta.aggregates import StopHooksAggregate

qqq = StopHooksAggregate.from_hooks(hooks.stop_hooks.stop_hook_approx_threshold)
# qqq

# %%
from skrough.algorithms import hooks
from skrough.algorithms.meta.aggregates import StopHooksAggregate

qqq = StopHooksAggregate.from_hooks(
    [
        hooks.stop_hooks.stop_hook_approx_threshold,
        hooks.stop_hooks.stop_hook_approx_threshold,
        hooks.stop_hooks.stop_hook_approx_threshold,
        hooks.stop_hooks.stop_hook_approx_threshold,
    ]
)
qqq
# Out:
# StopHooksAggregate(normalized_hooks=[<function stop_hook_approx_threshold at 0x7fe1a0c601f0>, <function stop_hook_approx_threshold at 0x7fe1a0c601f0>, <function stop_hook_approx_threshold at 0x7fe1a0c601f0>, <function stop_hook_approx_threshold at 0x7fe1a0c601f0>])

# %%
import numpy as np

from skrough.algorithms import hooks
from skrough.algorithms.hooks.names import (
    CONFIG_CANDIDATES_MAX_COUNT,
    CONFIG_CHAOS_FUN,
    CONFIG_CONSECUTIVE_EMPTY_ITERATIONS_MAX_COUNT,
    CONFIG_DAAR_ALLOWED_RANDOMNESS,
    CONFIG_DAAR_N_OF_PROBES,
    CONFIG_EPSILON,
    CONFIG_SELECT_ATTRS_CHAOS_SCORE_BASED_MAX_COUNT,
    INPUT_X,
    INPUT_Y,
    VALUES_CHAOS_SCORE_APPROX_THRESHOLD,
    VALUES_CHAOS_SCORE_BASE,
    VALUES_CHAOS_SCORE_TOTAL,
    VALUES_GROUP_INDEX,
    VALUES_RESULT_ATTRS,
    VALUES_RESULT_OBJS,
    VALUES_X,
    VALUES_X_COUNTS,
    VALUES_Y,
    VALUES_Y_COUNT,
)
from skrough.algorithms.meta import processing, stage
from skrough.chaos_measures import entropy, gini_impurity
from skrough.chaos_score import get_chaos_score_stats
from skrough.structs.state import ProcessingState

grow_stage = stage.Stage.from_hooks(
    stop_hooks=[
        hooks.stop_hooks.stop_hook_approx_threshold,
        # hooks.stop_hooks.stop_hook_empty_iterations,
    ],
    init_hooks=None,
    pre_candidates_hooks=[
        hooks.pre_candidates_hooks.pre_candidates_hook_remaining_attrs,
        hooks.pre_candidates_hooks.pre_candidates_hook_remaining_attrs,
        hooks.pre_candidates_hooks.pre_candidates_hook_remaining_attrs,
        hooks.pre_candidates_hooks.pre_candidates_hook_remaining_attrs,
    ],
    # candidates_hooks=hooks.common.process_elements.process_elements_hook_pass_everything,
    candidates_hooks=hooks.common.process_elements.create_process_elements_hook_random_choice(
        CONFIG_CANDIDATES_MAX_COUNT
    ),
    select_hooks=[
        hooks.select_hooks.select_hook_attrs_chaos_score_based,
    ],
    # filter_hooks=hooks.filter_hooks.filter_hook_attrs_first_daar,
    filter_hooks=None,
    # inner_init_hooks=hooks.inner_init_hooks.inner_init_hook_consecutive_empty_iterations_count,
    inner_init_hooks=None,
    inner_stop_hooks=hooks.inner_stop_hooks.inner_stop_hook_empty,
    inner_process_hooks=hooks.inner_process_hooks.inner_process_hook_add_first_attr,
    finalize_hooks=None,
)


msfun = processing.ProcessingMultiStage.from_hooks(
    init_multi_stage_hooks=[
        hooks.init_hooks.init_hook_factorize_data_x_y,
        hooks.init_hooks.init_hook_approx_threshold,
        hooks.init_hooks.init_hook_result_attrs_empty,
        hooks.init_hooks.init_hook_single_group_index,
    ],
    stages=[grow_stage],
    finalize_hooks=None,
    prepare_result_fun=hooks.prepare_result_hooks.prepare_result_hook_attrs_subset,
)


def compute():
    return msfun(
        input_data={
            INPUT_X: df_train.to_numpy(),
            INPUT_Y: target_train,
        },
        config={
            CONFIG_CHAOS_FUN: entropy,
            CONFIG_EPSILON: 0.05,
            CONFIG_SELECT_ATTRS_CHAOS_SCORE_BASED_MAX_COUNT: 1,
            CONFIG_CANDIDATES_MAX_COUNT: 50,
            # CONFIG_DAAR_ALLOWED_RANDOMNESS: 0.2,
            # CONFIG_DAAR_N_OF_PROBES: 100,
            # CONFIG_CONSECUTIVE_EMPTY_ITERATIONS_MAX_COUNT: 1,
        },
    )


# compute()

# %%
msfun
# Out:
# ProcessingMultiStage(init_multi_stage_agg=UpdateStateHooksAggregate(normalized_hooks=[<function init_hook_factorize_data_x_y at 0x7fdd79ebe3b0>, <function init_hook_approx_threshold at 0x7fdd79ebe830>, <function init_hook_result_attrs_empty at 0x7fdd79ebe710>, <function init_hook_single_group_index at 0x7fdd79ebe4d0>]), init_agg=UpdateStateHooksAggregate(normalized_hooks=[]), stages=[Stage(stop_agg=StopHooksAggregate(normalized_hooks=[<function stop_hook_approx_threshold at 0x7fdd79ebf9a0>]), init_agg=UpdateStateHooksAggregate(normalized_hooks=[]), pre_candidates_agg=ProduceElementsHooksAggregate(normalized_hooks=[<function pre_candidates_hook_remaining_attrs at 0x7fdd79ebf1c0>, <function pre_candidates_hook_remaining_attrs at 0x7fdd79ebf1c0>, <function pre_candidates_hook_remaining_attrs at 0x7fdd79ebf1c0>, <function pre_candidates_hook_remaining_attrs at 0x7fdd79ebf1c0>]), candidates_agg=ProcessElementsHooksAggregate(normalized_hooks=[<function create_process_elements_hook_random_choice.<locals>.process_elements_hook_random_choice at 0x7fdd79ebd630>]), select_agg=ProcessElementsHooksAggregate(normalized_hooks=[<function select_hook_attrs_chaos_score_based at 0x7fdd79ebf760>]), filter_agg=ChainProcessElementsHooksAggregate(normalized_hooks=[]), inner_init_agg=ChainProcessElementsHooksAggregate(normalized_hooks=[]), inner_stop_agg=InnerStopHooksAggregate(normalized_hooks=[<function inner_stop_hook_empty at 0x7fdd79ebef80>]), inner_process_agg=ChainProcessElementsHooksAggregate(normalized_hooks=[<function inner_process_hook_add_first_attr at 0x7fdd79ebed40>]), finalize_agg=UpdateStateHooksAggregate(normalized_hooks=[]))], finalize_agg=UpdateStateHooksAggregate(normalized_hooks=[]), prepare_result_fun=<function prepare_result_hook_attrs_subset at 0x7fdd79ebf400>)

# %%
import json
from dataclasses import asdict

print(json.dumps(asdict(grow_stage.describe()), indent=2))
# Out:
# {
#   "node_name": null,
#   "node_meta": null,
#   "name": "Stage",
#   "short_description": null,
#   "long_description": null,
#   "children": [
#     {
#       "node_name": "init",
#       "node_meta": null,
#       "name": "UpdateStateHooksAggregate",
#       "short_description": null,
#       "long_description": null,
#       "children": []
#     },
#     {
#       "node_name": "check_stop",
#       "node_meta": null,
#       "name": "StopHooksAggregate",
#       "short_description": null,
#       "long_description": null,
#       "children": [
#         {
#           "node_name": null,
#           "node_meta": null,
#           "name": "stop_hook_approx_threshold",
#           "short_description": "Stop check based on an expected level of approximation.",
#           "long_description": "Stop check based on an expected level of approximation. The function implements a\ncheck whether the current chaos score computed using the contents of the ``config``\nand ``values`` containers stored in the computation's state reached the expected\napproximation level maintained in the state object's values by some other\ncomplementary hook(s) under the ``HOOKS_APPROX_CHAOS_SCORE_VALUE_THRESHOLD`` key\nconstant. The stop check uses the values stored under the following key constants to\ncompute the current chaos score: ``HOOKS_CHAOS_FUN`` (``config``),\n``HOOKS_GROUP_INDEX`` (``values``), ``HOOKS_DATA_Y`` (``values``),\n``HOOKS_DATA_Y_COUNT`` (``values``).",
#           "children": null
#         }
#       ]
#     },
#     {
#       "node_name": "outer_loop",
#       "node_meta": null,
#       "name": null,
#       "short_description": null,
#       "long_description": null,
#       "children": [
#         {
#           "node_name": "pre_candidates",
#           "node_meta": null,
#           "name": "ProduceElementsHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": [
#             {
#               "node_name": null,
#               "node_meta": null,
#               "name": "pre_candidates_hook_remaining_attrs",
#               "short_description": null,
#               "long_description": null,
#               "children": null
#             }
#           ]
#         },
#         {
#           "node_name": "candidates",
#           "node_meta": null,
#           "name": "ProcessElementsHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": [
#             {
#               "node_name": null,
#               "node_meta": null,
#               "name": "process_elements_hook_random_choice",
#               "short_description": null,
#               "long_description": null,
#               "children": null
#             }
#           ]
#         },
#         {
#           "node_name": "select",
#           "node_meta": null,
#           "name": "ProcessElementsHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": [
#             {
#               "node_name": null,
#               "node_meta": null,
#               "name": "select_hook_attrs_chaos_score_based",
#               "short_description": null,
#               "long_description": null,
#               "children": null
#             }
#           ]
#         },
#         {
#           "node_name": "filter",
#           "node_meta": null,
#           "name": "ChainProcessElementsHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": []
#         },
#         {
#           "node_name": "inner_init",
#           "node_meta": null,
#           "name": "ChainProcessElementsHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": []
#         },
#         {
#           "node_name": "inner_loop",
#           "node_meta": null,
#           "name": null,
#           "short_description": null,
#           "long_description": null,
#           "children": [
#             {
#               "node_name": "inner_check_stop",
#               "node_meta": null,
#               "name": "InnerStopHooksAggregate",
#               "short_description": null,
#               "long_description": null,
#               "children": [
#                 {
#                   "node_name": null,
#                   "node_meta": null,
#                   "name": "inner_stop_hook_empty",
#                   "short_description": null,
#                   "long_description": null,
#                   "children": null
#                 }
#               ]
#             },
#             {
#               "node_name": "inner_process",
#               "node_meta": null,
#               "name": "ChainProcessElementsHooksAggregate",
#               "short_description": null,
#               "long_description": null,
#               "children": [
#                 {
#                   "node_name": null,
#                   "node_meta": null,
#                   "name": "inner_process_hook_add_first_attr",
#                   "short_description": null,
#                   "long_description": null,
#                   "children": null
#                 }
#               ]
#             },
#             {
#               "node_name": "check_stop",
#               "node_meta": null,
#               "name": "StopHooksAggregate",
#               "short_description": null,
#               "long_description": null,
#               "children": [
#                 {
#                   "node_name": null,
#                   "node_meta": null,
#                   "name": "stop_hook_approx_threshold",
#                   "short_description": "Stop check based on an expected level of approximation.",
#                   "long_description": "Stop check based on an expected level of approximation. The function implements a\ncheck whether the current chaos score computed using the contents of the ``config``\nand ``values`` containers stored in the computation's state reached the expected\napproximation level maintained in the state object's values by some other\ncomplementary hook(s) under the ``HOOKS_APPROX_CHAOS_SCORE_VALUE_THRESHOLD`` key\nconstant. The stop check uses the values stored under the following key constants to\ncompute the current chaos score: ``HOOKS_CHAOS_FUN`` (``config``),\n``HOOKS_GROUP_INDEX`` (``values``), ``HOOKS_DATA_Y`` (``values``),\n``HOOKS_DATA_Y_COUNT`` (``values``).",
#                   "children": null
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "node_name": "check_stop",
#           "node_meta": {
#             "optional": true
#           },
#           "name": "StopHooksAggregate",
#           "short_description": null,
#           "long_description": null,
#           "children": [
#             {
#               "node_name": null,
#               "node_meta": null,
#               "name": "stop_hook_approx_threshold",
#               "short_description": "Stop check based on an expected level of approximation.",
#               "long_description": "Stop check based on an expected level of approximation. The function implements a\ncheck whether the current chaos score computed using the contents of the ``config``\nand ``values`` containers stored in the computation's state reached the expected\napproximation level maintained in the state object's values by some other\ncomplementary hook(s) under the ``HOOKS_APPROX_CHAOS_SCORE_VALUE_THRESHOLD`` key\nconstant. The stop check uses the values stored under the following key constants to\ncompute the current chaos score: ``HOOKS_CHAOS_FUN`` (``config``),\n``HOOKS_GROUP_INDEX`` (``values``), ``HOOKS_DATA_Y`` (``values``),\n``HOOKS_DATA_Y_COUNT`` (``values``).",
#               "children": null
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "node_name": "finalize",
#       "node_meta": null,
#       "name": "UpdateStateHooksAggregate",
#       "short_description": null,
#       "long_description": null,
#       "children": []
#     }
#   ]
# }

# %%
# import joblib
# result = joblib.Parallel(n_jobs=4)(
#             joblib.delayed(compute)()
#             for _ in range(10)
#         )
# result
